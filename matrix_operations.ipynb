# %%
import unittest
import sympy as sym
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('MBhPaqKRehg', width=800, height=400)

# %%
YouTubeVideo('NcIAd0ho43g', width=800, height=400)

# %%
sym.init_printing(use_latex="mathjax")

# %%
B = sym.Matrix([[1, 2], [3, 4], [7, 5]])

# %%
B
# Out:
# ⎡1  2⎤
# ⎢    ⎥
# ⎢3  4⎥
# ⎢    ⎥
# ⎣7  5⎦

# %%
B[0,:]
# Out:
# [1  2]

# %%
A = sym.diag(3, 4, 5)

# %%
type(A)
# Out:
# sympy.matrices.dense.MutableDenseMatrix

# %%
B.T * A
# Out:
# ⎡3  12  35⎤
# ⎢         ⎥
# ⎣6  16  25⎦

# %%
sym.ones(4) + sym.eye(4)
# Out:
# ⎡2  1  1  1⎤
# ⎢          ⎥
# ⎢1  2  1  1⎥
# ⎢          ⎥
# ⎢1  1  2  1⎥
# ⎢          ⎥
# ⎣1  1  1  2⎦

# %%
sym.zeros(3)
# Out:
# ⎡0  0  0⎤
# ⎢       ⎥
# ⎢0  0  0⎥
# ⎢       ⎥
# ⎣0  0  0⎦

# %%
sym.Matrix([[3,4],[5,7]])
# Out:
# ⎡3  4⎤
# ⎢    ⎥
# ⎣5  7⎦

# %%
sym.eye(3)
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
YouTubeVideo('SNdzRI_yqIo', width=800, height=400)

# %%
x, y = sym.symbols("x y")

# %%
x**2
# Out:
#  2
# x

# %%
a11, a12, a21, a22, b11, b12, b21, b22 = sym.symbols("a11, a12, a21, a22, b11, b12, b21, b22")

# %%
A = sym.Matrix([[a11, a12], [a21, a22]])
B = sym.Matrix([[b11, b12], [b21, b22]])

# %%
A , B
# Out:
# ⎛⎡a₁₁  a₁₂⎤  ⎡b₁₁  b₁₂⎤⎞
# ⎜⎢        ⎥, ⎢        ⎥⎟
# ⎝⎣a₂₁  a₂₂⎦  ⎣b₂₁  b₂₂⎦⎠

# %%
3 * A
# Out:
# ⎡3⋅a₁₁  3⋅a₁₂⎤
# ⎢            ⎥
# ⎣3⋅a₂₁  3⋅a₂₂⎦

# %%
A * 3
# Out:
# ⎡3⋅a₁₁  3⋅a₁₂⎤
# ⎢            ⎥
# ⎣3⋅a₂₁  3⋅a₂₂⎦

# %%
A + B
# Out:
# ⎡a₁₁ + b₁₁  a₁₂ + b₁₂⎤
# ⎢                    ⎥
# ⎣a₂₁ + b₂₁  a₂₂ + b₂₂⎦

# %%
A * B
# Out:
# ⎡a₁₁⋅b₁₁ + a₁₂⋅b₂₁  a₁₁⋅b₁₂ + a₁₂⋅b₂₂⎤
# ⎢                                    ⎥
# ⎣a₂₁⋅b₁₁ + a₂₂⋅b₂₁  a₂₁⋅b₁₂ + a₂₂⋅b₂₂⎦

# %%
YouTubeVideo('rqP1EWoAiVc', width=800, height=400)

# %%
from sympy import Matrix

# %%
A = Matrix([[1,2,3], [4,5,6], [10, 11, 9]])
A
# Out:
# ⎡1   2   3⎤
# ⎢         ⎥
# ⎢4   5   6⎥
# ⎢         ⎥
# ⎣10  11  9⎦

# %%
L, U, _ = A.LUdecomposition()

# %%
A == L*U
# Out:
# True

# %%
L
# Out:
# ⎡1   0  0⎤
# ⎢        ⎥
# ⎢4   1  0⎥
# ⎢        ⎥
# ⎣10  3  1⎦

# %%
U
# Out:
# ⎡1  2   3 ⎤
# ⎢         ⎥
# ⎢0  -3  -6⎥
# ⎢         ⎥
# ⎣0  0   -3⎦

# %%
YouTubeVideo('vvq4VdYQOJY', width=800, height=400)

# %%
from sympy import Matrix, init_printing

# %% [markdown]
# $$ A \underline{x} = \underline{b} $$

# %%
A1 = Matrix([[3, 4, 1, 0], [4, 5, 0, 1]])
A1
# Out:
# ⎡3  4  1  0⎤
# ⎢          ⎥
# ⎣4  5  0  1⎦

# %%
A1.rref()
# Out:
# ⎛⎡1  0  -5  4 ⎤        ⎞
# ⎜⎢            ⎥, (0, 1)⎟
# ⎝⎣0  1  4   -3⎦        ⎠

# %%
A2 = Matrix([[3, 4], [4, 5]])
A2.inv()
# Out:
# ⎡-5  4 ⎤
# ⎢      ⎥
# ⎣4   -3⎦

# %%
A2.inv(method='LU')
# Out:
# ⎡-5  4 ⎤
# ⎢      ⎥
# ⎣4   -3⎦

# %%
YouTubeVideo('FgXp28Abllw', width=800, height=400)

# %%
def add(a, b):
    return a + b

# %%
class TestNotebook(unittest.TestCase):

    def test_add(self):
        self.assertEqual(add(2, 2), 4)
    def test_type(self):
        self.assertIsInstance(add(1, 1), int)


unittest.main(argv=[''], verbosity=2, exit=False)
